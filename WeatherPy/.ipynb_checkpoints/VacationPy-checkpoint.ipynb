# %%
# !pip install gmaps
# Out:
# Requirement already satisfied: gmaps in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (0.9.0)
# Requirement already satisfied: geojson>=2.0.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: ipython>=5.3.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from gmaps) (8.0.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from gmaps) (7.6.5)
# Requirement already satisfied: six in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from gmaps) (5.1.1)
# Requirement already satisfied: stack-data in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (0.1.4)
# Requirement already satisfied: pygments in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (2.11.2)
# Requirement already satisfied: backcall in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (58.0.4)
# Requirement already satisfied: black in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (22.1.0)
# Requirement already satisfied: pickleshare in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: appnope in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (0.18.1)
# Requirement already satisfied: decorator in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipython>=5.3.0->gmaps) (3.0.26)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->gmaps) (6.8.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.3)
# Requirement already satisfied: jupyter-client<8.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (7.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: nest-asyncio in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.3)
# Requirement already satisfied: jupyter-core in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.9.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.8)
# Requirement already satisfied: platformdirs>=2 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from black->ipython>=5.3.0->gmaps) (2.4.1)
# Requirement already satisfied: tomli>=1.1.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from black->ipython>=5.3.0->gmaps) (2.0.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from black->ipython>=5.3.0->gmaps) (0.4.3)
# Requirement already satisfied: click>=8.0.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from black->ipython>=5.3.0->gmaps) (8.0.3)
# Requirement already satisfied: pathspec>=0.9.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from black->ipython>=5.3.0->gmaps) (0.9.0)
# Requirement already satisfied: executing in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->gmaps) (0.8.2)
# Requirement already satisfied: asttokens in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->gmaps) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->gmaps) (0.2.2)
# Requirement already satisfied: attrs>=17.4.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.18.1)
# Requirement already satisfied: entrypoints in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (0.4)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (22.3.0)
# Requirement already satisfied: nbconvert in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: jinja2 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.0.3)
# Requirement already satisfied: prometheus-client in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: argon2-cffi in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.1)
# Requirement already satisfied: bleach in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.1.0)
# Requirement already satisfied: defusedxml in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.10)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: testpath in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.15.0)
# Requirement already satisfied: packaging in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3)
# Requirement already satisfied: webencodings in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pycparser in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/rolandoportal/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.0.7)

# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

from collections.abc import Iterable


# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#Load csv file created in Part 1
city_data_csv = "output_data/cities_myhw.csv"
#Turn csv into DataFrame
city_data_df = pd.read_csv(city_data_csv)
city_data_df
# Out:
#            City Country        Date      Lat       Lng  Max Temp  Humidity  \
# 0    porto novo      BJ  1643912886   6.4965    2.6036     84.02        64
# 1         kapaa      US  1643912886  22.0752 -159.3190     71.92        77
# 2       itarema      BR  1643912887  -2.9248  -39.9167     85.23        65
# 3        pyapon      MM  1643912888  16.2833   95.6833     68.25        65
# 4       rikitea      PF  1643912683 -23.1203 -134.9692     77.36        77
# ..          ...     ...         ...      ...       ...       ...       ...
# 554        aden      YE  1643913160  12.7794   45.0367     78.13        60
# 555     rutland      US  1643913008  43.6167  -73.0162     42.24        94
# 556  revelstoke      CA  1643913161  50.9832 -118.2023     17.62        93
# 557   sanchursk      RU  1643913161  56.9413   47.2499      4.37       100
# 558  port hardy      CA  1643913162  50.6996 -127.4199     42.76        93
#
#      Cloudiness  Wind Speed
# 0            75        8.39
# 1            20       11.50
# 2            78       16.22
# 3            14        5.97
# 4           100       14.41
# ..          ...         ...
# 554           0        9.44
# 555         100        1.01
# 556         100        0.00
# 557         100        3.13
# 558         100       13.80
#
# [559 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.
# * Drop any rows will null values.

# %%
#Configure gmaps
gmaps.configure(api_key = g_key)

# %%
#Cleaning data by dropping nan values
city_data_df = city_data_df.dropna()
city_data_df
# Out:
#            City Country        Date      Lat       Lng  Max Temp  Humidity  \
# 0    porto novo      BJ  1643912886   6.4965    2.6036     84.02        64
# 1         kapaa      US  1643912886  22.0752 -159.3190     71.92        77
# 2       itarema      BR  1643912887  -2.9248  -39.9167     85.23        65
# 3        pyapon      MM  1643912888  16.2833   95.6833     68.25        65
# 4       rikitea      PF  1643912683 -23.1203 -134.9692     77.36        77
# ..          ...     ...         ...      ...       ...       ...       ...
# 554        aden      YE  1643913160  12.7794   45.0367     78.13        60
# 555     rutland      US  1643913008  43.6167  -73.0162     42.24        94
# 556  revelstoke      CA  1643913161  50.9832 -118.2023     17.62        93
# 557   sanchursk      RU  1643913161  56.9413   47.2499      4.37       100
# 558  port hardy      CA  1643913162  50.6996 -127.4199     42.76        93
#
#      Cloudiness  Wind Speed
# 0            75        8.39
# 1            20       11.50
# 2            78       16.22
# 3            14        5.97
# 4           100       14.41
# ..          ...         ...
# 554           0        9.44
# 555         100        1.01
# 556         100        0.00
# 557         100        3.13
# 558         100       13.80
#
# [556 rows x 9 columns]

# %%
#Use the Lat and Lng as locations
locations = city_data_df[["Lat","Lng"]].astype(float)
humidity = city_data_df["Humidity"]

# %%
# Create a humidity heatmap layer
fig = gmaps.figure(center = [0,0] ,zoom_level = 2)

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 2)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.

# %%
#Narrow down the cities to fit weather conditions
perfect_weather_city_df = city_data_df.loc[(city_data_df["Max Temp"] <= 80)
                                          &(city_data_df["Max Temp"] >= 70)
                                          &(city_data_df["Wind Speed"] <= 10)
                                          &(city_data_df["Cloudiness"] == 0),:].dropna()
perfect_weather_city_df
# Out:
#               City Country        Date      Lat       Lng  Max Temp  Humidity  \
# 76   mar del plata      AR  1643912682 -38.0023  -57.5575     73.87        83
# 105       ahuimanu      US  1643912934  21.4447 -157.8378     74.46        72
# 106     sao filipe      CV  1643912910  14.8961  -24.4956     75.20        68
# 258  makakilo city      US  1643913011  21.3469 -158.0858     73.29        69
# 292          pisco      PE  1643913028 -13.7000  -76.2167     74.01        78
# 325       douentza      ML  1643913045  14.9951   -2.9517     75.92        11
# 452       araouane      ML  1643913108  18.9048   -3.5265     71.91         9
# 467       kalmunai      LK  1643913115   7.4167   81.8167     74.93        78
# 554           aden      YE  1643913160  12.7794   45.0367     78.13        60
#
#      Cloudiness  Wind Speed
# 76            0        4.61
# 105           0        1.01
# 106           0        7.65
# 258           0        4.61
# 292           0        8.05
# 325           0        7.52
# 452           0        9.48
# 467           0        2.15
# 554           0        9.44

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = perfect_weather_city_df.copy()
hotel_df["Hotel Name"] = " "
hotel_df
# Out:
#               City Country        Date      Lat       Lng  Max Temp  Humidity  \
# 76   mar del plata      AR  1643912682 -38.0023  -57.5575     73.87        83
# 105       ahuimanu      US  1643912934  21.4447 -157.8378     74.46        72
# 106     sao filipe      CV  1643912910  14.8961  -24.4956     75.20        68
# 258  makakilo city      US  1643913011  21.3469 -158.0858     73.29        69
# 292          pisco      PE  1643913028 -13.7000  -76.2167     74.01        78
# 325       douentza      ML  1643913045  14.9951   -2.9517     75.92        11
# 452       araouane      ML  1643913108  18.9048   -3.5265     71.91         9
# 467       kalmunai      LK  1643913115   7.4167   81.8167     74.93        78
# 554           aden      YE  1643913160  12.7794   45.0367     78.13        60
#
#      Cloudiness  Wind Speed Hotel Name
# 76            0        4.61
# 105           0        1.01
# 106           0        7.65
# 258           0        4.61
# 292           0        8.05
# 325           0        7.52
# 452           0        9.48
# 467           0        2.15
# 554           0        9.44

# %%
#Set parameters to search for hotels with 5000 meters.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "radius": 5000,
    "type": "hotel",
    "keyword": "lodging",
    "key": g_key
         }

# %%
# use iterrows to iterate through pandas dataframe
for index, row in hotel_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    city_name = row["City"]
    
     # add location to params dict
    params["location"] = f"{lat},{lng}"
    
    # assemble url and make API request
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    print(f"Retrieving Results for Index {index}: {city_name}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        print(f"Closest hotel is {results[0]['name']}.")
        hotel_df.loc[index, "Hotel Name"] = results[0]['name']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for Index 76: mar del plata.
# Closest hotel is Casa Daupi.
# ------------
# Retrieving Results for Index 105: ahuimanu.
# Closest hotel is Paradise Bay Resort.
# ------------
# Retrieving Results for Index 106: sao filipe.
# Closest hotel is La Fora Ecolodge.
# ------------
# Retrieving Results for Index 258: makakilo city.
# Closest hotel is Barber's Point and ITT and Beach Cottages.
# ------------
# Retrieving Results for Index 292: pisco.
# Closest hotel is PiscoMar Peru.
# ------------
# Retrieving Results for Index 325: douentza.
# Closest hotel is Ogomono Doumbo.
# ------------
# Retrieving Results for Index 452: araouane.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 467: kalmunai.
# Closest hotel is Villa LUXEZ.
# ------------
# Retrieving Results for Index 554: aden.
# Closest hotel is Crater Palace Hotel.
# ------------

# %%
 hotel_df
# Out:
#               City Country        Date      Lat       Lng  Max Temp  Humidity  \
# 76   mar del plata      AR  1643912682 -38.0023  -57.5575     73.87        83
# 105       ahuimanu      US  1643912934  21.4447 -157.8378     74.46        72
# 106     sao filipe      CV  1643912910  14.8961  -24.4956     75.20        68
# 258  makakilo city      US  1643913011  21.3469 -158.0858     73.29        69
# 292          pisco      PE  1643913028 -13.7000  -76.2167     74.01        78
# 325       douentza      ML  1643913045  14.9951   -2.9517     75.92        11
# 452       araouane      ML  1643913108  18.9048   -3.5265     71.91         9
# 467       kalmunai      LK  1643913115   7.4167   81.8167     74.93        78
# 554           aden      YE  1643913160  12.7794   45.0367     78.13        60
#
#      Cloudiness  Wind Speed                                 Hotel Name
# 76            0        4.61                                 Casa Daupi
# 105           0        1.01                        Paradise Bay Resort
# 106           0        7.65                           La Fora Ecolodge
# 258           0        4.61  Barber's Point and ITT and Beach Cottages
# 292           0        8.05                              PiscoMar Peru
# 325           0        7.52                             Ogomono Doumbo
# 452           0        9.48
# 467           0        2.15                                Villa LUXEZ
# 554           0        9.44                        Crater Palace Hotel

# %%
# NOTE: Do not change any of the code in this cell

    
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
# Add the layer to the map
fig.add_layer(marker_layer)
# Display figure
fig
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <module>
#       1 # Add marker layer ontop of heat map
# ----> 2 marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
#       3 # Add the layer to the map
#       4 fig.add_layer(marker_layer)
#
# File ~/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages/gmaps/marker.py:553, in marker_layer(locations, hover_text, label, info_box_content, display_info_box)
#     485 @doc_subst(_doc_snippets)
#     486 def marker_layer(
#     487         locations, hover_text='', label='',
#     488         info_box_content=None, display_info_box=None):
#     489     """
#     490     Marker layer
#     491
#    (...)
#     551         A :class:`gmaps.Markers` instance.
#     552     """
# --> 553     marker_options = _marker_layer_options(
#     554         locations, hover_text, label, info_box_content, display_info_box)
#     555     markers = [Marker(**option) for option in marker_options]
#     556     return Markers(markers=markers)
#
# File ~/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages/gmaps/marker.py:311, in _marker_layer_options(locations, hover_text, label, info_box_content, display_info_box)
#     309 if is_atomic(label):
#     310     label = [label] * number_markers
# --> 311 if is_atomic(info_box_content):
#     312     info_box_content = [info_box_content] * number_markers
#     314 marker_options = {
#     315     'location': locations_to_list(locations),
#     316     'hover_text': hover_text,
#     317     'label': label
#     318 }
#
# File ~/miniconda3/envs/name_of_my_env/lib/python3.10/site-packages/gmaps/options.py:40, in is_atomic(elem)
#      34 def is_atomic(elem):
#      35     """
#      36     True if an element is a single atom and false if it's a collection
#      37     """
#      38     return (
#      39         isinstance(elem, string_types) or
# ---> 40         not isinstance(elem, collections.Iterable)
#      41     )
#
# AttributeError: module 'collections' has no attribute 'Iterable'
